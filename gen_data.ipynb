# %%
# !pip install openai
# !conda env list
# Out:
# # conda environments:
# #
# base                     /home/sohampoddar/anaconda3
# dl                    *  /home/sohampoddar/anaconda3/envs/dl
# evokg                    /home/sohampoddar/anaconda3/envs/evokg
# hate                     /home/sohampoddar/anaconda3/envs/hate
# hatex                    /home/sohampoddar/anaconda3/envs/hatex
# itv2                     /home/sohampoddar/anaconda3/envs/itv2
# llm                      /home/sohampoddar/anaconda3/envs/llm
# opensora                 /home/sohampoddar/anaconda3/envs/opensora
# prune_llm                /home/sohampoddar/anaconda3/envs/prune_llm
# tkg                      /home/sohampoddar/anaconda3/envs/tkg
# tkg-py-3-11              /home/sohampoddar/anaconda3/envs/tkg-py-3-11
# vllm                     /home/sohampoddar/anaconda3/envs/vllm
#                          /home/sohampoddar/rohit_mtp/.conda

# %%
import openai

# %%
# !pip install -r requirements.txt
# !pip install datasets
# !pip install transformers
# !pip install evaluate
# !pip install -q evaluate rouge_score
# !pip install transformers peft torch
# !pip install bitsandbytes
# !pip install git+https://github.com/huggingface/transformers.git
# !pip install git+https://github.com/huggingface/peft.git
# Out:
# Requirement already satisfied: pandas in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: transformers in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (4.44.2)
# Requirement already satisfied: openai in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: sentencepiece in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.1.99)
# Requirement already satisfied: datasets in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (2.17.1)
# Requirement already satisfied: torch in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (1.25.1)
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (0.23.3)
# Requirement already satisfied: packaging>=20.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (2023.6.3)
# Requirement already satisfied: requests in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from openai->-r requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from openai->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from openai->-r requirements.txt (line 3)) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from openai->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: sniffio in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from openai->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from openai->-r requirements.txt (line 3)) (4.11.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.3.8)
# Requirement already satisfied: xxhash in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: multiprocess in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 5)) (3.9.3)
# Requirement already satisfied: sympy in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (1.12)
# Requirement already satisfied: networkx in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (3.1)
# Requirement already satisfied: jinja2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->-r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->-r requirements.txt (line 6)) (12.4.127)
# Requirement already satisfied: idna>=2.8 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 5)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 5)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: certifi in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 3)) (2.16.2)
# Requirement already satisfied: six>=1.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from jinja2->torch->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from sympy->torch->-r requirements.txt (line 6)) (1.3.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: datasets in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (2.17.1)
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (3.12.2)
# Requirement already satisfied: numpy>=1.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (1.25.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (0.23.3)
# Requirement already satisfied: packaging in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: transformers in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (4.44.2)
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (0.23.3)
# Requirement already satisfied: numpy>=1.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (2023.7.22)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: evaluate in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (0.4.1)
# Requirement already satisfied: datasets>=2.0.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (2.17.1)
# Requirement already satisfied: numpy>=1.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (1.25.1)
# Requirement already satisfied: dill in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (0.23.3)
# Requirement already satisfied: packaging in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (23.1)
# Requirement already satisfied: responses<0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.12.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: transformers in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (4.44.2)
# Requirement already satisfied: peft in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: torch in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (0.23.3)
# Requirement already satisfied: numpy>=1.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: psutil in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft) (5.9.0)
# Requirement already satisfied: accelerate>=0.21.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft) (0.29.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: bitsandbytes in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (0.43.1)
# Requirement already satisfied: torch in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from bitsandbytes) (2.3.0)
# Requirement already satisfied: numpy in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from bitsandbytes) (1.25.1)
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (3.12.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (4.11.0)
# Requirement already satisfied: sympy in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (1.12)
# Requirement already satisfied: networkx in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (3.1)
# Requirement already satisfied: jinja2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch->bitsandbytes) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from jinja2->torch->bitsandbytes) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-pjv8s5rc
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-pjv8s5rc
#   Resolved https://github.com/huggingface/transformers.git to commit d9e6f307e71b5108a7882ec00ffcc0d0eb316cb7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.24.0 (from transformers==4.47.0.dev0)
#   Obtaining dependency information for huggingface-hub<1.0,>=0.24.0 from https://files.pythonhosted.org/packages/60/bf/cea0b9720c32fa01b0c4ec4b16b9f4ae34ca106b202ebbae9f03ab98cd8f/huggingface_hub-0.26.2-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (2.31.0)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.47.0.dev0)
#   Obtaining dependency information for tokenizers<0.21,>=0.20 from https://files.pythonhosted.org/packages/29/9e/c95f8821d6bc93eba7c5db95e6299c009db523d1c646da8563b42ad892c4/tokenizers-0.20.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tokenizers-0.20.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers==4.47.0.dev0) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.47.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.47.0.dev0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers==4.47.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers==4.47.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers==4.47.0.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->transformers==4.47.0.dev0) (2023.7.22)
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 2.9 MB/s eta 0:00:0000:0100:01
# Downloading tokenizers-0.20.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 15.9 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.47.0.dev0-py3-none-any.whl size=10100444 sha256=996b096d431ced61bada7d0b78d18554f324ce6e20c877ff10b25b422bb38c46
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m0w6pfkn/wheels/f7/92/8c/752ff3bfcd3439805d8bbf641614da38ef3226e127ebea86ee
# Successfully built transformers
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.23.3
#     Uninstalling huggingface-hub-0.23.3:
#       Successfully uninstalled huggingface-hub-0.23.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cohere 5.5.6 requires tokenizers<0.16,>=0.15, but you have tokenizers 0.20.3 which is incompatible.
# Successfully installed huggingface-hub-0.26.2 tokenizers-0.20.3 transformers-4.47.0.dev0
# Collecting git+https://github.com/huggingface/peft.git
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-5yv4de3y
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-5yv4de3y
#   Resolved https://github.com/huggingface/peft.git to commit eaaf03c12767c9d3dbc9edca7766cfcb799c38a0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (23.1)
# Requirement already satisfied: psutil in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (5.9.0)
# Requirement already satisfied: pyyaml in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (2.3.0)
# Requirement already satisfied: transformers in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (4.47.0.dev0)
# Requirement already satisfied: tqdm in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (4.65.0)
# Requirement already satisfied: accelerate>=0.21.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (0.29.3)
# Requirement already satisfied: safetensors in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (0.4.2)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from peft==0.13.3.dev0) (0.26.2)
# Requirement already satisfied: filelock in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface_hub>=0.25.0->peft==0.13.3.dev0) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface_hub>=0.25.0->peft==0.13.3.dev0) (2023.6.0)
# Requirement already satisfied: requests in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface_hub>=0.25.0->peft==0.13.3.dev0) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from huggingface_hub>=0.25.0->peft==0.13.3.dev0) (4.11.0)
# Requirement already satisfied: sympy in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (1.12)
# Requirement already satisfied: networkx in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (3.1)
# Requirement already satisfied: jinja2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from torch>=1.13.0->peft==0.13.3.dev0) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft==0.13.3.dev0) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->peft==0.13.3.dev0) (2023.6.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from transformers->peft==0.13.3.dev0) (0.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from jinja2->torch>=1.13.0->peft==0.13.3.dev0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->huggingface_hub>=0.25.0->peft==0.13.3.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->huggingface_hub>=0.25.0->peft==0.13.3.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->huggingface_hub>=0.25.0->peft==0.13.3.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from requests->huggingface_hub>=0.25.0->peft==0.13.3.dev0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /home/sohampoddar/anaconda3/envs/dl/lib/python3.9/site-packages (from sympy->torch>=1.13.0->peft==0.13.3.dev0) (1.3.0)
# Building wheels for collected packages: peft
#   Building wheel for peft (pyproject.toml) ... done
#   Created wheel for peft: filename=peft-0.13.3.dev0-py3-none-any.whl size=373388 sha256=155f47be2e419f66c63b113655cda0f18a4c6808bd34f151d5dcede8f6fb9dcb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2odinzef/wheels/2d/60/1b/0edd9dc0f0c489738b1166bc1b0b560ee368f7721f89d06e3a
# Successfully built peft
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: peft
#   Attempting uninstall: peft
#     Found existing installation: peft 0.10.0
#     Uninstalling peft-0.10.0:
#       Successfully uninstalled peft-0.10.0
# Successfully installed peft-0.13.3.dev0

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(3) if torch.cuda.is_available() else "No GPU")
# Out:
# GPU Available: True
# GPU Name: NVIDIA RTX A6000

# %%
device = torch.device("cuda:1")

# %%
device.type
# Out:
# 'cuda'

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"
openai.api_key = os.getenv("OPENAI_API_KEY")
print(openai.api_key)
# Out:
# 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

# %%
import pandas as pd
import os

# read the data
train_data=pd.read_csv('/home/sohampoddar/HDD2/utsav/Dataset/train.csv')

train_data.__len__
# Out:
# <bound method DataFrame.__len__ of                         ID                                               text  \
# 0     1311981051720409089t  @sandraburgess3 They have no idea , they cant ...
# 1     1361403925845401601t  @stepheniscowboy Nvm I ’ ve had covid I ’ ve g...
# 2     1293488278361055233t  Coronavirus updates : Government partners with...
# 3     1305252218526990338t  @OANN U . K . Glaxo Smith Klein whistleblower ...
# 4     1376135683400687618t  3 / horse " AstraZeneca , not so much for the ...
# ...                    ...                                                ...
# 6952  1370403012842250241t  I don ’ t get the flu shot . Haven ’ t gotten ...
# 6953  1337580201560125442t  Why are they rushing this vaccine out ? COVID ...
# 6954  1351838450706763777t  @SJJB55 ' Cases ' data is propaganda . Where /...
# 6955  1333970612897808385t  @holly_go_litely @jmask @JustinTrudeau Moderna...
# 6956  1342131267446263808t  @breckyunits @social_brains @jayvanbavel @mode...
#
#                   labels
# 0            ineffective
# 1            unnecessary
# 2                 pharma
# 3                 rushed
# 4     ineffective pharma
# ...                  ...
# 6952                none
# 6953  rushed side-effect
# 6954                none
# 6955              pharma
# 6956              rushed
#
# [6957 rows x 3 columns]>

# %%
test_data=pd.read_csv('/home/sohampoddar/HDD2/utsav/Dataset/test.csv')
test_data.__len__
# Out:
# <bound method DataFrame.__len__ of                         ID                                               text  \
# 0     1329097028845105155t  @nbc4i Please everyone research Pfizer ’ s his...
# 1     1340017965828349952t  EVEN WITH A VACCINE IT IS STILL NOT ENOUGH . T...
# 2     1329126491649683459t  @ianbrown @DarrenPlymouth It ’ s the unknown l...
# 3     1285666197003018240t  @FACT_Exeter @K3T3R @respect65 Back to my orig...
# 4     1284814348679028737t  @DrJasonJohnson IMHO optimistic talk about a v...
# ...                    ...                                                ...
# 1972  1278716521645174784t  CREEPY PLOTS & PLANS Covid - 19 was discovered...
# 1973  1331183322463080452t  @KingOfWrong And yet still they are foisting a...
# 1974  1265552247888515078t  @BardsFM Never , no never will my husband and ...
# 1975  1254812267755057153t  @guardian Ask your paymaster Bill Gates why al...
# 1976  1285981188285333505t  @AstraiosT @o_rips Alberta better not force a ...
#
#                                 labels
# 0                               pharma
# 1                 conspiracy political
# 2                          side-effect
# 3                               rushed
# 4                          ineffective
# ...                                ...
# 1972  conspiracy mandatory side-effect
# 1973                  mandatory pharma
# 1974           ingredients unnecessary
# 1975              conspiracy mandatory
# 1976                 country mandatory
#
# [1977 rows x 3 columns]>

# %%
val_data= pd.read_csv('/home/sohampoddar/HDD2/utsav/Dataset/val.csv')

# %% [markdown]
# Variations with Prompts

# %%
data=val_data

# %% [markdown]
# From Each Class

# %%
# take only those labels which have more than one labels example ineffective unnecessary
data = data[data['labels'].str.split().apply(len) > 1]
print(len(data))
data.head()
# Out:
# 186
#                         ID                                               text  \
# 2457  1344293646095556615t  Now this is what I've been afraid of what will...
# 1761  1312005944012804096t  @TheRickWilson 2 possibilities : 1 . It is wha...
# 594   1355912154508103680t  Amen ! If the plandemic were a pandemic , no o...
# 1494  1287260291810590720t  Yes , we know . And just like the vaccine for ...
# 3471  1251244613689585665t  Overall , pushing for a vaccine for an unknown...
#
#                        labels
# 2457  ineffective side-effect
# 1761  pharma political rushed
# 594        rushed unnecessary
# 1494     conspiracy religious
# 3471       pharma unnecessary

# %%
texts = data['text']
label= data['labels']

# %% [markdown]
# While it may be frustrating that the Prime Minister has not yet set up a call with the CEO of Pfizer, it is important to remember that there are many factors at play in the procurement and distribution of vaccines. Just because a call has not been made does not mean that the government does not care about the well-being of its citizens or the importance of vaccination. It is unfair to make such harsh assumptions without all the information.---3.5
#
#
# While it's understandable to feel frustrated with political leaders during a public health crisis, dismissing the efforts made to vaccinate the population overlooks the importance of community health. Vaccines have been proven to save lives and prevent the spread of infectious diseases. It's crucial to engage in constructive dialogue rather than spreading misinformation or personal attacks. Holding leaders accountable is important, but promoting vaccine skepticism can have serious consequences for public health and safety. Instead, we should focus on supporting science-based solutions that benefit everyone. --4o-mini

# %%
import csv
from openai import OpenAI
client = OpenAI()
results=[]

with open('prompts3_multilabels.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Label', 'Prompt', 'Generated Counter Argument']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for lab, text in zip(label, texts):
        # Create a prompt with the text
        # if there are more than one labels then only do else continue

        prompt = f"Give a short counterpoint to the statement in this anti-vaccine tweet:\n{text}\n\n"

        # print(prompt)
        # Generate the completion
        completion = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": prompt}]
        )
        generated_text = completion.choices[0].message.content
        # print(generated_text)
        # Write the result to the CSV file
        writer.writerow({
            'Label': lab,
            'Prompt': prompt,
            'Generated Counter Argument': generated_text
        })

        # Also store in the list for future use if needed
        results.append(generated_text)

print("All results have been saved to 'counter_arguments_prompt3.csv'.")
# Out:
# All results have been saved to 'counter_arguments_prompt3.csv'.

# %%
import csv
from openai import OpenAI
client = OpenAI()
results=[]

with open('prompts4_multilabels.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Label', 'Prompt', 'Generated Counter Argument']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for lab, text in zip(label, texts):
        # Create a prompt with the text
        # if there are more than one labels then only do else continue

        prompt = f"Generate a concise response challenging this tweet:\n{text}\n\n"

        # print(prompt)
        # Generate the completion
        completion = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": prompt}]
        )
        generated_text = completion.choices[0].message.content
        # print(generated_text)
        # Write the result to the CSV file
        writer.writerow({
            'Label': lab,
            'Prompt': prompt,
            'Generated Counter Argument': generated_text
        })

        # Also store in the list for future use if needed
        results.append(generated_text)

print("All results have been saved to 'counter_arguments_prompt3.csv'.")
# Out:
# All results have been saved to 'counter_arguments_prompt3.csv'.

# %%
import csv
from openai import OpenAI
client = OpenAI()
results=[]

with open('prompts5_multilabels.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Label', 'Prompt', 'Generated Counter Argument']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for lab, text in zip(label, texts):
        # if there are more than one labels then only do else continue

        prompt = f"Write a succinct counter-argument against this tweet:\n{text}\n\n"

        # print(prompt)
        # Generate the completion
        completion = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": prompt}]
        )
        generated_text = completion.choices[0].message.content
        # print(generated_text)
        # Write the result to the CSV file
        writer.writerow({
            'Label': lab,
            'Prompt': prompt,
            'Generated Counter Argument': generated_text
        })

        # Also store in the list for future use if needed
        results.append(generated_text)

print("All results have been saved to 'counter_arguments_prompt3.csv'.")
# Out:
# All results have been saved to 'counter_arguments_prompt3.csv'.

# %% [markdown]
# Label Description Incoporation

# %%
labels_map = {}
labels_map['religious'] = "religious beliefs and their influence on views about vaccines"
labels_map['political'] = "the political factors that affect perceptions of vaccine use"
labels_map['ingredients'] = "concerns about the ingredients and chemical components in vaccines"
labels_map['unnecessary'] = "the importance and necessity of getting vaccinated to prevent diseases"
labels_map['conspiracy'] = "conspiracy theories suggesting hidden motives behind vaccination efforts"
labels_map['mandatory'] = "the debate over personal choice versus mandates in vaccination policies"
labels_map['ineffective'] = "evidence and reasons that support the effectiveness of vaccines"
labels_map['side-effect'] = "potential side effects and adverse reactions associated with vaccines"
labels_map['pharma'] = "the role of pharmaceutical companies and concerns about profit motives"
labels_map['rushed'] = "claims that vaccines were approved or developed without sufficient testing"
labels_map['country'] = "national biases and objections to vaccines produced by specific countries"

# %%
train_data.__len__
# Out:
# <bound method DataFrame.__len__ of                         ID                                               text  \
# 0     1311981051720409089t  @sandraburgess3 They have no idea , they cant ...
# 1     1361403925845401601t  @stepheniscowboy Nvm I ’ ve had covid I ’ ve g...
# 2     1293488278361055233t  Coronavirus updates : Government partners with...
# 3     1305252218526990338t  @OANN U . K . Glaxo Smith Klein whistleblower ...
# 4     1376135683400687618t  3 / horse " AstraZeneca , not so much for the ...
# ...                    ...                                                ...
# 6952  1370403012842250241t  I don ’ t get the flu shot . Haven ’ t gotten ...
# 6953  1337580201560125442t  Why are they rushing this vaccine out ? COVID ...
# 6954  1351838450706763777t  @SJJB55 ' Cases ' data is propaganda . Where /...
# 6955  1333970612897808385t  @holly_go_litely @jmask @JustinTrudeau Moderna...
# 6956  1342131267446263808t  @breckyunits @social_brains @jayvanbavel @mode...
#
#                   labels
# 0            ineffective
# 1            unnecessary
# 2                 pharma
# 3                 rushed
# 4     ineffective pharma
# ...                  ...
# 6952                none
# 6953  rushed side-effect
# 6954                none
# 6955              pharma
# 6956              rushed
#
# [6957 rows x 3 columns]>

# %%
# take sample 10 data
data=train_data.sample(2000)
texts = data['text']
label= data['labels']

# %%
import csv
from openai import OpenAI
client = OpenAI()
results=[]

with open('val_data_with_labels_desc.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Label', 'Prompt', 'Generated Counter Argument']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for lab, text in zip(label, texts):
        # if there are more than one labels then only do else continue

            prompt = f"Generate a brief counter argument for the anti-vaccine tweet:\n{text}\nTalk About "
            lab = lab.split()
            # print(lab)
            if isinstance(lab, list):
                # print("List")
                mapped_labels = " and ".join([labels_map.get(l, "") for l in lab])  # Use get to handle potential missing keys
            else:
                # print('Not list')
                mapped_labels = labels_map.get(lab, "")  # Handle the case where lab is a single string
            prompt += mapped_labels
            # print("Prompt is:",prompt,"\n")
            # Generate the completion
            completion = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ]
            )
            generated_text = completion.choices[0].message.content

            # Write the result to the CSV file
            writer.writerow({
                'Label': lab,
                'Prompt': prompt,
                'Generated Counter Argument': generated_text
            })
